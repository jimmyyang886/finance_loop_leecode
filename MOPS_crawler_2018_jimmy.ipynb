# %% [markdown]
# # Main function

# %%
import requests
from requests.adapters import HTTPAdapter
from bs4 import BeautifulSoup as bs4
import re
import pandas as pd
import numpy as np
import json

class MOPS_ALL_2018(object):
    
    def __init__(self, sid, year, season, rid):
        self.sid=sid
        self.year=year
        self.season=season
        self.rid=rid
        keyword={'sid':self.sid, 'y':self.year, 's':self.season, 'rid':self.rid}
        self.header= {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Safari/537.36'}
        self.url='https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID={sid}&SYEAR={y}&SSEASON={s}&REPORT_ID={rid}'.format(**keyword)
        self.get_tbl()
        
    def fetchall(self):
        self.fetch_BS()
        self.fetch_PLS()
        self.fetch_CFS()
        #self.fetch_SES()
        self.jsondata = {'data': [self.Balance, self.ProfitLoss , self.CashFlows]}
        
        return self.jsondata        
    
    def get_tbl(self):
        web_ss = requests.session()
        ss_adapter = HTTPAdapter(max_retries=3)
        web_ss.mount("https://", adapter=ss_adapter)
        res = web_ss.get(url=self.url, headers=self.header, timeout=5)
        res.encoding = 'big5'
        try:
            if res.status_code == 200:
                #soup = bs4(res.text, "lxml")
                soup = bs4(res.text, "lxml")
                self.tables = soup.select('table')
        except Exception as e:
            print(e)
            
        return self.tables
            
            
    def fetch_BS(self, Ntable=1):
        tr_list = self.tables[Ntable].select('tr')
        
        Balance_list = []
        for tr in tr_list:
            td_list = tr.select("td")
            if len(td_list) != 0:
                row = []
                for i in td_list:
    
                    level=i.text.count(u'\u3000')
                    #print(i.text, level)
                    #print(i.text, level)
                    p=i.text.strip().replace(',','')
                    #p=i.text.replace(',','')
                    if re.search(u'[\u4e00-\u9fff]', p):
                        row.append([level, p])
                    else:
                        row.append(p)
                        
                        
                        
                if len(row) > 0:
                    Balance_list.append(row[:2])

#         self.Balance = pd.DataFrame(tbl, columns = ['cht','value'])
#         self.Balance = self.Balance[self.Balance['value'] != '']  
        
        self.Balance={'Balance':Balance_list}

        return self.Balance
        
    def fetch_PLS(self, Ntable=2):        
        tr_list = self.tables[Ntable].select('tr')
        
        ProfitLoss_list = []
        for tr in tr_list:
            td_list = tr.select("td")
            if len(td_list) != 0:
                row = []
                for i in td_list:
                    
                    level=i.text.count(u'\u3000')
                    p=i.text.strip().replace(',','')
                    if re.search(u'[\u4e00-\u9fff]', p):
                        row.append([level, p])
                    else:
                        row.append(p)
        #             print(i.text.strip().replace(',',''))
        #     print(tr.select("td"))
                if len(row) > 0:
                    ProfitLoss_list.append(row[:2])
        
#         self.ProfitLoss = pd.DataFrame(tbl, columns = ['cht','value'])
#         self.ProfitLoss = self.ProfitLoss[self.ProfitLoss['value'] != '']  
        self.ProfitLoss={'ProfitLoss':ProfitLoss_list}
        return self.ProfitLoss
    
    
        
    def fetch_CFS(self, Ntable = 3):
        tr_list = self.tables[Ntable].select('tr')
        
        CashFlows_list = []
        for tr in tr_list:
            td_list = tr.select("td")
            if len(td_list) != 0:
                row = []
                for i in td_list:
                    level=i.text.count(u'\u3000')
                    p=i.text.strip().replace(',','')
                    if re.search(u'[\u4e00-\u9fff]', p):
                        row.append([level, p])
                    else:
                        row.append(p)
        #     print(tr.select("td"))
                if len(row) > 0:
                    CashFlows_list.append(row[:2])
        
#         self.CashFlows = pd.DataFrame(tbl, columns = ['cht','value'])
#         self.CashFlows = self.CashFlows[self.CashFlows['value'] != '']  
         
        self.CashFlows={'CashFlows':CashFlows_list}
        return self.CashFlows
        
        
    def fetch_SES(self, Ntable = 4):

        Etable = self.tables[Ntable]
        #print(Etable)
#         print(len(Etable.select("tr")))
        
        tr_list = Etable.select("tr")
        tbl = []
        column = []
        
        for tr in tr_list:
            td_list = tr.select("td") #row
            th_list = tr.select("th") #column
        
            row = []
            for td in td_list:
                row.append(td.text.replace("\n","").replace(",",""))
            if len(row) > 0:
                tbl.append(row)
            
            for th in th_list:
                column.append(th.text.replace("\n",""))
#         print(len(tbl))
#         print(column)
        self.equity_dict = {'col_index':column,'row_value':tbl}
#         print(self.equity_dict)
        return self.equity_dict
        
#         self.equity = pd.DataFrame(tbl,columns = column)


#         self.equity = self.equity.replace("", np.nan)
#         self.equity = self.equity.fillna(0)
#         self.equity['items'] = self.equity.iloc[:,0]
#         self.equity = self.equity.iloc[:,1:]
        
#         self.equity.set_index('items', inplace=True) 
#         return self.equity
#         return print(tbl)

# %%
year='2017'
season='3'
code='3031'
rid='C'
stock=MOPS_ALL_2018(code,year,season,rid)
data = stock.fetchall()
data
# Out:
# {'data': [{'Balance': [[[1, '資產'], ''],
#     [[2, '流動資產'], ''],
#     [[3, '現金及約當現金'], ''],
#     [[4, '現金及約當現金總額'], '532105'],
#     [[3, '透過損益按公允價值衡量之金融資產－流動'], ''],
#     [[4, '透過損益按公允價值衡量之金融資產－流動合計'], '100234'],
#     [[3, '應收票據淨額'], ''],
#     [[4, '應收票據淨額'], '60058'],
#     [[3, '應收帳款淨額'], ''],
#     [[4, '應收帳款淨額'], '476343'],
#     [[3, '應收帳款－關係人淨額'], ''],
#     [[4, '應收帳款－關係人淨額'], '87583'],
#     [[3, '應收建造合約款'], '215896'],
#     [[3, '當期所得稅資產'], ''],
#     [[4, '本期所得稅資產合計'], '0'],
#     [[3, '存貨'], ''],
#     [[4, '存貨合計'], '324816'],
#     [[3, '其他流動資產'], ''],
#     [[4, '其他金融資產－流動'], '318422'],
#     [[4, '其他流動資產－其他'], '29969'],
#     [[4, '其他流動資產合計'], '348391'],
#     [[3, '流動資產合計'], '2145426'],
#     [[2, '非流動資產'], ''],
#     [[3, '備供出售金融資產－非流動'], ''],
#     [[4, '備供出售金融資產－非流動淨額'], '181592'],
#     [[3, '以成本衡量之金融資產－非流動'], ''],
#     [[4, '以成本衡量之金融資產－非流動淨額'], '319330'],
#     [[3, '採用權益法之投資'], ''],
#     [[4, '採用權益法之投資淨額'], '121950'],
#     [[3, '不動產、廠房及設備'], ''],
#     [[4, '不動產、廠房及設備合計'], '766283'],
#     [[3, '遞延所得稅資產'], '19908'],
#     [[3, '其他非流動資產'], ''],
#     [[4, '存出保證金'], '16287'],
#     [[4, '其他非流動資產－其他'], ''],
#     [[5, '其他非流動資產－其他合計'], '25111'],
#     [[4, '其他非流動資產合計'], '41398'],
#     [[3, '非流動資產合計'], '1450461'],
#     [[2, '資產總計'], '3595887'],
#     [[1, '負債及權益'], ''],
#     [[2, '負債'], ''],
#     [[3, '流動負債'], ''],
#     [[4, '短期借款'], ''],
#     [[5, '短期借款合計'], '70000'],
#     [[4, '應付帳款'], ''],
#     [[5, '應付帳款合計'], '325636'],
#     [[4, '應付帳款－關係人'], ''],
#     [[5, '應付帳款－關係人合計'], '30003'],
#     [[4, '本期所得稅負債'], '1712'],
#     [[4, '其他流動負債'], ''],
#     [[5, '一年或一營業週期內到期長期負債'], ''],
#     [[6, '一年或一營業週期內到期長期借款'], '23515'],
#     [[6, '一年或一營業週期內到期長期負債合計'], '23515'],
#     [[5, '其他流動負債－其他'], '197369'],
#     [[5, '其他流動負債合計'], '220884'],
#     [[4, '流動負債合計'], '648235'],
#     [[3, '非流動負債'], ''],
#     [[4, '長期借款'], ''],
#     [[5, '長期借款合計'], '42604'],
#     [[4, '遞延所得稅負債'], ''],
#     [[5, '遞延所得稅負債合計'], '2110'],
#     [[4, '其他非流動負債'], ''],
#     [[5, '淨確定福利負債-非流動'], '31065'],
#     [[5, '其他非流動負債－其他'], '20619'],
#     [[5, '其他非流動負債合計'], '51684'],
#     [[4, '非流動負債合計'], '96398'],
#     [[3, '負債總計'], '744633'],
#     [[2, '權益'], ''],
#     [[3, '歸屬於母公司業主之權益'], ''],
#     [[4, '股本'], ''],
#     [[5, '普通股股本'], '1866742'],
#     [[5, '股本合計'], '1866742'],
#     [[4, '資本公積'], ''],
#     [[5, '資本公積合計'], '441536'],
#     [[4, '保留盈餘'], ''],
#     [[5, '保留盈餘合計'], '428117'],
#     [[4, '其他權益'], ''],
#     [[5, '其他權益合計'], '-59461'],
#     [[4, '庫藏股票'], '0'],
#     [[4, '歸屬於母公司業主之權益合計'], '2676934'],
#     [[3, '非控制權益'], '174320'],
#     [[3, '權益總額'], '2851254'],
#     [[2, '負債及權益總計'], '3595887'],
#     [[2, '待註銷股本股數'], '0'],
#     [[2, '預收股款（權益項下）之約當發行股數'], '0'],
#     [[2, '母公司暨子公司所持有之母公司庫藏股股數（單位：股）'], '0']]},
#   {'ProfitLoss': [[[1, '營業收入'], ''],
#     [[2, '營業收入合計'], '513783'],
#     [[1, '營業成本'], ''],
#     [[2, '銷貨成本'], ''],
#     [[3, '銷貨成本合計'], '388659'],
#     [[2, '營業成本合計'], '388659'],
#     [[1, '營業毛利（毛損）'], '125124'],
#     [[1, '營業毛利（毛損）淨額'], '125124'],
#     [[1, '營業費用'], ''],
#     [[2, '推銷費用'], ''],
#     [[3, '推銷費用合計'], '14323'],
#     [[2, '管理費用'], ''],
#     [[3, '管理費用合計'], '76938'],
#     [[2, '研究發展費用'], ''],
#     [[3, '研究發展費用合計'], '4540'],
#     [[2, '營業費用合計'], '95801'],
#     [[1, '營業利益（損失）'], '29323'],
#     [[1, '營業外收入及支出'], ''],
#     [[2, '其他收入'], ''],
#     [[3, '其他收入合計'], '15360'],
#     [[2, '其他利益及損失'], ''],
#     [[3, '其他利益及損失淨額'], '12259'],
#     [[2, '財務成本'], ''],
#     [[3, '財務成本淨額'], '772'],
#     [[2, '採用權益法之關聯企業及合資損益之份額'], ''],
#     [[3, '採用權益法認列之關聯企業及合資損失之份額'], '-3235'],
#     [[3, '採用權益法認列之關聯企業及合資損益之份額淨額'], '3235'],
#     [[2, '營業外收入及支出合計'], '30082'],
#     [[1, '繼續營業單位稅前淨利（淨損）'], '59405'],
#     [[1, '所得稅費用（利益）'], ''],
#     [[2, '所得稅費用（利益）合計'], '8852'],
#     [[1, '繼續營業單位本期淨利（淨損）'], '50553'],
#     [[1, '本期淨利（淨損）'], '50553'],
#     [[1, '其他綜合損益(淨額)'], ''],
#     [[2, '後續可能重分類至損益之項目'], ''],
#     [[3, '國外營運機構財務報表換算之兌換差額'], '-19759'],
#     [[3, '備供出售金融資產未實現評價損益'], '18132'],
#     [[3, '後續可能重分類至損益之項目總額'], '-1627'],
#     [[2, '其他綜合損益（淨額）'], '-1627'],
#     [[1, '本期綜合損益總額'], '48926'],
#     [[1, '淨利（損）歸屬於：'], ''],
#     [[2, '母公司業主（淨利／損）'], '59553'],
#     [[2, '非控制權益（淨利／損）'], '-9000'],
#     [[1, '綜合損益總額歸屬於：'], ''],
#     [[2, '母公司業主（綜合損益）'], '55471'],
#     [[2, '非控制權益（綜合損益）'], '-6545'],
#     [[1, '基本每股盈餘'], ''],
#     [[2, '基本每股盈餘合計'], '0.32']]},
#   {'CashFlows': [[[1, '營業活動之現金流量－間接法'], ''],
#     [[2, '繼續營業單位稅前淨利（淨損）'], '138402'],
#     [[2, '本期稅前淨利（淨損）'], '138402'],
#     [[2, '調整項目'], ''],
#     [[3, '收益費損項目'], ''],
#     [[4, '折舊費用'], '80486'],
#     [[4, '攤銷費用'], '2983'],
#     [[4, '呆帳費用提列（轉列收入）數'], '-6501'],
#     [[4, '透過損益按公允價值衡量金融資產及負債之淨損失（利益）'], '-234'],
#     [[4, '利息費用'], '2139'],
#     [[4, '利息收入'], '-4330'],
#     [[4, '股利收入'], '-22546'],
#     [[4, '股份基礎給付酬勞成本'], '0'],
#     [[4, '採用權益法認列之關聯企業及合資損失（利益）之份額'], '-1485'],
#     [[4, '處分及報廢不動產、廠房及設備損失（利益）'], '527'],
#     [[4, '處分投資損失（利益）'], '45'],
#     [[4, '收益費損項目合計'], '51084'],
#     [[3, '與營業活動相關之資產／負債變動數'], ''],
#     [[4, '與營業活動相關之資產之淨變動'], ''],
#     [[5, '應收票據（增加）減少'], '15385'],
#     [[5, '應收帳款（增加）減少'], '8581'],
#     [[5, '應收帳款－關係人（增加）減少'], '-35470'],
#     [[5, '應收建造合約款（增加）減少'], '-25753'],
#     [[5, '存貨（增加）減少'], '-1205'],
#     [[5, '其他流動資產（增加）減少'], '10798'],
#     [[5, '其他金融資產（增加）減少'], '0'],
#     [[5, '與營業活動相關之資產之淨變動合計'], '-27664'],
#     [[4, '與營業活動相關之負債之淨變動'], ''],
#     [[5, '應付帳款增加（減少）'], '-23596'],
#     [[5, '應付帳款－關係人增加（減少）'], '-9420'],
#     [[5, '其他流動負債增加（減少）'], '-16819'],
#     [[5, '淨確定福利負債增加(減少)'], '-2334'],
#     [[5, '與營業活動相關之負債之淨變動合計'], '-52169'],
#     [[4, '與營業活動相關之資產及負債之淨變動合計'], '-79833'],
#     [[3, '調整項目合計'], '-28749'],
#     [[2, '營運產生之現金流入（流出）'], '109653'],
#     [[2, '收取之利息'], '4340'],
#     [[2, '支付之利息'], '-2139'],
#     [[2, '退還（支付）之所得稅'], '-30376'],
#     [[1, '營業活動之淨現金流入（流出）'], '81478'],
#     [[1, '投資活動之現金流量'], ''],
#     [[2, '取得透過其他綜合損益按公允價值衡量之金融資產'], '-100000'],
#     [[2, '取得備供出售金融資產'], '-13753'],
#     [[2, '處分備供出售金融資產'], '4923'],
#     [[2, '取得以成本衡量之金融資產'], '0'],
#     [[2, '取得不動產、廠房及設備'], '-26723'],
#     [[2, '處分不動產、廠房及設備'], '124'],
#     [[2, '存出保證金減少'], '4982'],
#     [[2, '其他金融資產增加'], '0'],
#     [[2, '其他金融資產減少'], '69753'],
#     [[2, '其他非流動資產增加'], '0'],
#     [[2, '其他非流動資產減少'], '7915'],
#     [[2, '收取之股利'], '22546'],
#     [[2, '投資活動之淨現金流入（流出）'], '-30233'],
#     [[1, '籌資活動之現金流量'], ''],
#     [[2, '償還長期借款'], '-17635'],
#     [[2, '其他非流動負債增加'], '8018'],
#     [[2, '其他非流動負債減少'], '0'],
#     [[2, '發放現金股利'], '-149339'],
#     [[2, '庫藏股票買回成本'], '-27741'],
#     [[2, '籌資活動之淨現金流入（流出）'], '-186697'],
#     [[1, '匯率變動對現金及約當現金之影響'], '-60058'],
#     [[1, '本期現金及約當現金增加（減少）數'], '-195510'],
#     [[1, '期初現金及約當現金餘額'], '727615'],
#     [[1, '期末現金及約當現金餘額'], '532105'],
#     [[2, '資產負債表帳列之現金及約當現金'], '532105']]}]}

# %%
stock.url
# Out:
# 'https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=3031&SYEAR=2017&SSEASON=3&REPORT_ID=C'

# %% [markdown]
# # Fetch DATA

# %%
import os
import time
import random
from requests.exceptions import ConnectionError
from codes import codes


def dlcheck(path):
    filename=os.listdir(path)
    code_cap=[]
    for _file in filename:
        code_cap.append(_file[0:4])
    return code_cap

year='2017'
season='3'
path=year+'Q'+season
csvpath=year+'Q'+season+'SES'

if not os.path.exists(path):
    os.mkdir(path)

if not os.path.exists(csvpath):
    os.mkdir(csvpath)

#取得兩個資料夾的交集，以便確認是否抓過
code_cap=set(dlcheck(path)) & set(dlcheck(csvpath))
print(code_cap)


for code,v in codes.items():
    if v.type=="股票" and v.market=="上市":
        try:
            if code not in code_cap:
                rid ='C'           
                stock=MOPS_ALL_2018(code,year,season,rid)
#                 print(stock.tables)
                if len(stock.tables) < 3:
                    time.sleep(random.uniform(2,5))
                    rid = 'A'
                    stock=MOPS_ALL_2018(code,year,season,rid)
                    if len(stock.tables) < 3:
                        with open('nofinreport.txt', 'a') as f:
                            f.write('nodata:'+code+':'+stock.url+'\n')
                        print(stock.url)
                        print(code +' no finance data!')
                        continue
                    
                if stock.tables != []:
                    print('fetch BS, PLS and CFS from:' ,stock.url)
                    data = stock.fetchall()
                    filename=path+'/'+code+'-'+year+'-'+'Q'+season+'.json'
                    with open(filename, 'w', encoding='utf8') as f:
                        json.dump(data, f)
                    
                    
                    print('fetch SES from:' ,stock.url)

                    jsonname=csvpath+'/'+code+'-'+year+'-'+'Q'+season+'_ses.json'
                    ses_data = stock.fetch_SES()
                    with open(jsonname, 'w', encoding='utf8') as f:
                        json.dump(ses_data, f)
                        
                        
                else:
                    print('error-nodata:', code) 
                    with open('error.log', 'a+') as f:   
                        f.write('nodata:'+ code+':' + stock.url+'\n\n')
                time.sleep(random.uniform(2,5))             
                
        except ConnectionError:
            code_cap=set(dlcheck(path)) & set(dlcheck(csvpath))
            time.sleep(120)
            continue
print('download finished!')
# Out:
# set()
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1101&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1101&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1102&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1102&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1103&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1103&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1104&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1104&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1108&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1108&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1109&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1109&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1110&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1110&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1201&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1201&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1203&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1203&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1210&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1210&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1213&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1213&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1215&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1215&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1216&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1216&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1217&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1217&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1218&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1218&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1219&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1219&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1220&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1220&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1225&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1225&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1227&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1227&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1229&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1229&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1231&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1231&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1232&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1232&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1233&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1233&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1234&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1234&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1235&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1235&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1236&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1236&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1256&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1256&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1301&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1301&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1303&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1303&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1304&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1304&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1305&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1305&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1307&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1307&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1308&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1308&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1309&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1309&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1310&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1310&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1312&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1312&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1313&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1313&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1314&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1314&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1315&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1315&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1316&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1316&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1319&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1319&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1321&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1321&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1323&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1323&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1324&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1324&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1325&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1325&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1326&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1326&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1337&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1337&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1338&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1338&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1339&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1339&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1340&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1340&SYEAR=2017&SSEASON=3&REPORT_ID=C
# https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1341&SYEAR=2017&SSEASON=3&REPORT_ID=A
# 1341 no finance data!
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1402&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1402&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1409&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1409&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1410&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1410&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1413&SYEAR=2017&SSEASON=3&REPORT_ID=A
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1413&SYEAR=2017&SSEASON=3&REPORT_ID=A
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1414&SYEAR=2017&SSEASON=3&REPORT_ID=A
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1414&SYEAR=2017&SSEASON=3&REPORT_ID=A
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1416&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1416&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1417&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1417&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1418&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1418&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1419&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1419&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1423&SYEAR=2017&SSEASON=3&REPORT_ID=A
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1423&SYEAR=2017&SSEASON=3&REPORT_ID=A
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1432&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1432&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1434&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1434&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1435&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1435&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1436&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1436&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1437&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1437&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1438&SYEAR=2017&SSEASON=3&REPORT_ID=A
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1438&SYEAR=2017&SSEASON=3&REPORT_ID=A
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1439&SYEAR=2017&SSEASON=3&REPORT_ID=A
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1439&SYEAR=2017&SSEASON=3&REPORT_ID=A
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1440&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1440&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1441&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1441&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1442&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1442&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1443&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1443&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1444&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1444&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1445&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1445&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1446&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1446&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1447&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1447&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1449&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1449&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1451&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1451&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1452&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1452&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1453&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1453&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1454&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1454&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1455&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1455&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1456&SYEAR=2017&SSEASON=3&REPORT_ID=A
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1456&SYEAR=2017&SSEASON=3&REPORT_ID=A
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1457&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1457&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1459&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1459&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1460&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1460&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1463&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1463&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1464&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1464&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1465&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1465&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1466&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1466&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1467&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1467&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1468&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1468&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1470&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1470&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1471&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1471&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1472&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1472&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1473&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1473&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1474&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1474&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1475&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1475&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch BS, PLS and CFS from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1476&SYEAR=2017&SSEASON=3&REPORT_ID=C
# fetch SES from: https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1476&SYEAR=2017&SSEASON=3&REPORT_ID=C

# %%
stock.tables
# Out:
# [<table border="0" width="800px">
#  <tr>
#  <th align="center" nowrap="">公司代號：</th>
#  <td align="center" nowrap=""><input id="CO_ID" maxlength="6" name="CO_ID" size="15" type="text" value="1418"/></td>
#  <td align="center" nowrap=""><input id="qryId" name="qryId" onclick="showDialog('','/server-java/t164sb01?step=2','success');" type="button" value="代號查詢"/></td>
#  <th align="center" nowrap="">年度：</th>
#  <td align="center" nowrap=""> <select id="SYEAR" name="SYEAR"> <option value="2013"> 102 </option> <option value="2014"> 103 </option> <option value="2015"> 104 </option> <option value="2016"> 105 </option> <option selected="selected" value="2017"> 106 </option> <option value="2018"> 107 </option> <option value="2019"> 108 </option> <option value="2020"> 109 </option> <option value="2021"> 110 </option> </select> </td>
#  <th align="center" nowrap="">季別：</th>
#  <td align="center" nowrap=""><b>第 <select id="SSEASON" name="SSEASON"> <option value="1"> 1 </option> <option value="2"> 2 </option> <option selected="selected" value="3"> 3 </option> <option value="4"> 4 </option> </select> 季</b></td>
#  <th align="center" nowrap="">財報類別：</th>
#  <td align="center" nowrap=""> <select id="REPORT_ID" name="REPORT_ID"> <option selected="selected" value="C"> 合併財報 </option> <option value="A"> 個別財報 </option> <option value="B"> 個體財報 </option> </select> </td>
#  <td align="center" nowrap=""><input id="query" name="query" onclick="document.t164form.submit();" type="button" value="　查　詢　"/></td>
#  </tr>
#  </table>,
#  <table align="center" class="result_table hasBorder" style="border-collapse:collapse;" width="900"><tr class="tblHead"><th align="center">會計項目</th><th align="center" nowrap="">2017年09月30日</th><th align="center" nowrap="">2016年12月31日</th><th align="center" nowrap="">2016年09月30日</th></tr><tr class="tblHead"><th align="left" colspan="4" nowrap="">資產負債表</th></tr><tr class="odd"><td nowrap="">　 資產</td><td align="right"></td><td align="right"></td><td align="right"></td></tr><tr class="even"><td nowrap="">　　 流動資產</td><td align="right"></td><td align="right"></td><td align="right"></td></tr><tr class="odd"><td nowrap="">　　　 現金及約當現金</td><td align="right"></td><td align="right"></td><td align="right"></td></tr><tr class="even"><td nowrap="">　　　　 現金及約當現金總額</td><td align="right">                 23,932</td><td align="right">                 45,288</td><td align="right">                 37,439</td></tr><tr class="odd"><td nowrap="">　　　 備供出售金融資產－流動</td><td align="right"></td><td align="right"></td><td align="right"></td></tr
#  <table align="center" class="main_table hasBorder" style="border-collapse:collapse;" width="900"><tr class="tblHead"><th align="left" colspan="2">財報附註</th></tr><tr class="odd"><td colspan="2" nowrap="">公司沿革及業務範圍</td></tr><tr class="even"><td nowrap="" width="25%">　 公司沿革及業務範圍</td><td align="left"><pre style="font-family:細明體;">
#  　　東華合纖股份有限公司（以下簡稱「本公司」，本公司及由本公司
#  所控制個體以下簡稱「合併公司」）係中日合資公司，奉經濟部投資審
#  議委員會核准，依公司法及其他有關法令規定於59年3月2日設立，以產
#  銷「聚丙烯�藻X成纖維」（東華龍）為主要業務。
#  　　本公司股票自66年2月14日起於台灣證券交易所上市買賣。
#  　　本合併財務報告係以本公司之功能性貨幣新台幣表達。
#
#
#  </pre></td></tr><tr class="odd"><td colspan="2" nowrap="">通過財報之日期及程序</td></tr><tr class="even"><td nowrap="" width="25%">　 通過財報之日期及程序</td><td align="left"><pre style="font-family:細明體;">
#  　　本合併財務報表於106年11月7日經董事會通過。
#
#  </pre></td></tr><tr class="odd"><td nowrap="" width="25%">　 新發布及修訂準則及解釋之適用</td><td align="left"><pre style="font-family:細明體;">
#  (一)首次適用修正後之證券發行人財務報告編製準則及經金融監督管理
#      委員會（以下稱「金管會」）認可並發布生效之國際財務報導準則
#     （IFRS）、國際會計準則（IAS）、解釋（IFRIC）及解釋公告（SIC
#      ）（以下稱「IFRSs」）
#  　　    除下列說明外，適用修正後之證券發行人財務報告編製準則及
#      金管會認可並發布生效之IFRSs將不致造成合併公司會計政策之重
#      大變動：
#      證券發行人財務報告編製準則之修正
#  　　    該修正除配合金管會認可並發布生效之IFRSs新增若干會計項
#      目及非金融資產減損揭露規定外，另配合國內實施IFRSs情形，強
#      調若干認列與衡量規定，並新增關係人交易及商譽等揭露。
#  　　    該修正規定，其他公司或機構與合併公司之董事長或總經理為
#      同一人，或具有配偶或二親等以內關係者，除能證明不具控制或重
#      大影響者外，係屬實質關係人。此外，該修正規定應揭露與合併公
#      司進行交易之關係人名稱及關係，若單一關係人交易金額或餘額達
#      合併公司各該項交易總額或餘額10%以上者，應按關係人名稱單獨
#      列示。
#  　　    106年追溯適用前述修正時，係增加關係人交易之揭露，請參
#      閱附註二六。
#  (二)107年適用之證券發行人財務報告編製準則及金管會認可並發布生
#      效之IFRSs
#      新發布／修正／修訂準則及解釋       IASB發布之生效日（註1）
#      「2014-2016週期之年度改善」	       註2
#      IFRS 2之修正「股份基礎給付交易之   2018年1月1日
#      分類與衡量」
#      IFRS 4之修正「於IFRS 4『保險合約   2018年1月1日
#      』下IFRS 9『金融工具』之適用」
#      IFRS 9「金融工具」		       2018年1月1日
#      IFRS 9及IFRS 7之修正「強制生效日   2018年1月1日
#      及過渡揭露」
#      IFRS 15「客戶合約之收入」	       2018年1月1日
#      IFRS 15之修正「IFRS 15之闡釋」     2018年1月1日
#      IAS 7之修正「揭露倡議」	       2017年1月1日
#      IAS 12之修正「未實現損失之遞延所   2017年1月1日
#      得稅資產之認列」
#      IAS 40之修正「投資性不動產之轉換   2018年1月1日
#      」
#      IFRIC 22「外幣交易與預收付對價」   2018年1月1日
#
#      註1：除另註明外，上述新發布／修正／修訂準則或解釋係於各該
#           日期以後開始之年度期間生效。
#      註2：IFRS 12之修正係追溯適用於2017年1月1日以後開始之年度
#           期間；IAS 28之修正係追溯適用於2018年1月1日以後開始之
#           年度期間。
#      IFRS 9「金融工具」及相關修正－金融資產之認列、衡量與減損
#  　　    就金融資產方面，所有原屬於IAS 39「金融工具：認列與衡
#      量」範圍內之金融資產後續衡量係以攤銷後成本衡量或以公允價
#      值衡量。IFRS 9對金融資產之分類規定如下。
#  　　    合併公司投資之債務工具，若其合約現金流量完全為支付本
#      金及流通在外本金金額之利息，分類及衡量如下：
#      1.以收取合約現金流量為目的之經營模式而持有該金融資產，則
#        該金融資產係以攤銷後成本衡量。此類金融資產後續係按有效
#        利率認列利息收入於損益，並持續評估減損，減損損益認列於
#        損益。
#      2.藉由收取合約現金流量與出售金融資產而達成目的之經營模式
#        而持有該金融資產，則該金融資產係以透過其他綜合損益按公
#        允價值衡量。此類金融資產後續係按有效利率認列利息收入於
#        損益，並持續評估減損，減損損益與兌換損益亦認列於損益，
#        其他公允價值變動則認列於其他綜合損益。於該金融資產除列
#        或重分類時，原先累積於其他綜合損益之公允價值變動應重分
#        類至損益。
#  　　    合併公司投資非屬前述條件之金融資產，係以公允價值衡量
#      ，公允價值變動認列於損益。惟合併公司得選擇於原始認列時，
#      將非持有供交易之權益投資指定為透過其他綜合損益按公允價值
#      衡量。此類金融資產除股利收益認列於損益外，其他相關利益及
#      損失係認列於其他綜合損益，後續無須評估減損，累積於其他綜
#      合損益之公允價值變動亦不重分類至損益。
#  　　    合併公司暫以106年9月30日持有之金融資產與當日所存在之
#      事實及情況，初步評估下列金融資產之分類與衡量將因適用IFRS
#      9而改變：
#  　　   分類為備供出售金融資產之上市（櫃）及興櫃股票與未上市
#     （櫃）股票投資，依IFRS 9選擇指定為透過其他綜合損益按公允
#      價值衡量，累計於其他權益，於投資處分時不再重分類至損益，
#      而將直接轉入保留盈餘。
#  　　    除上述影響外，截至本合併財務報告通過發布日止，合併公
#      司仍持續評估其他準則、解釋之修正對財務狀況與財務績效之影
#      響，相關影響待評估完成時予以揭露。
#
#  (三)IASB已發布但尚未經金管會認可並發布生效之IFRSs（註1）
#      新發布／修正／修訂準則及解釋	    IASB發布之生效日
#      IFRS 9之修正「具負補償之提前還款特      2019年1月1日
#      性」
#      IFRS 10及IAS 28之修正「投資者與其       未定
#      關聯企業或合資間之資產出售或投入」
#      IFRS 16「租賃」		            2019年1月1日
#      IFRS 17「保險合約」  		    2021年1月1日
#      IAS 28之修正「對關聯企業及合資之長      2019年1月1日
#      期權益」
#      IFRIC 23「所得稅之不確定性之處理」	    2019年1月1日
#
#      註：除另註明外，上述新發布／修正／修訂準則或解釋係於各該
#          日期以後開始之年度期間生效。
#      IFRS 16「租賃」
#  　　    IFRS 16係規範租賃之會計處理，該準則將取代IAS 17「租
#      賃」及相關解釋。
#  　　    於適用IFRS 16時，若合併公司為承租人，除低價值標的資
#      產租賃及短期租賃得選擇採用類似IAS 17之營業租賃處理外，
#      其他租賃皆應於合併資產負債表上認列使用權資產及租賃負債。
#      合併綜合損益表應分別表達使用權資產之折舊費用及租賃負債按
#      有效利息法所產生之利息費用。在合併現金流量表中，償付租賃
#      負債之本金金額表達為籌資活動，支付利息部分則列為營業活動
#      。
#  　　    對於合併公司為出租人之會計處理預計無重大影響。
#  　　    IFRS 16生效時，合併公司得選擇追溯適用至比較期間或將
#      首次適用之累積影響數認列於首次適用日。
#  　　    除上述影響外，截至本合併財務報告通過發布日止，合併公
#      司仍持續評估其他準則、解釋之修正對財務狀況與財務績效之影
#      響，相關影響待評估完成時予以揭露。
#
#
#  </pre></td></tr><tr class="even"><td colspan="2" nowrap="">重大會計政策之彙總說明</td></tr><tr class="odd"><td nowrap="" width="25%">　 遵循聲明</td><td align="left"><pre style="font-family:細明體;">
#  　　本合併財務報告係依照證券發行人財務報告編製準則及經金管
#  會認可並發布生效之IAS 34「期中財務報導」編製。本合併財務報
#  告並未包含整份年度財務報告所規定之所有IFRSs揭露資訊。
#
#  </pre></td></tr><tr class="even"><td nowrap="" width="25%">　 編製基礎</td><td align="left"><pre style="font-family:細明體;">
#  　　除按公允價值衡量之金融工具及按確定福利義務現值減除計畫
#  資產公允價值認列之淨確定福利負債外，本合併財務報告係依歷史
#  成本基礎編製。
#  　　公允價值衡量依照相關輸入值之可觀察程度及重要性分為第1
#  等級至第3等級：
#  1.第1等級輸入值：係指於衡量日可取得之相同資產或負債於活絡
#    市場之報價（未經調整）。
#  2.第2等級輸入值：係指除第1等級之報價外，資產或負債直接（
#    亦即價格）或間接（亦即由價格推導而得）之可觀察輸入值。
#  3.第3等級輸入值：係指資產或負債之不可觀察之輸入值。
#  　　本公司截至106年9月30日止之待彌補虧損為245,911仟元，流
#  動比率為33%，負債比率為96%。本公司隨主要原料國際價格漲幅變
#  動劇烈之影響，導致產品售價無法隨成本漲幅調整，以及中國大陸
#  地區同業低價競爭，致使營運持續虧損，因此本公司對繼續經營之
#  能力可能產生重大疑慮；惟106年第3季合併財務報表仍按繼續經營
#  基礎編製。
#  　　本公司擬採取下列對策以改善營運狀況及強化財務結構：
#  (1)營運方面
#     A.建構生產、銷售、採購一體化平台，整合產銷購資訊，優化
#       由產品接單銷售至生產製造及原料採購的流程，降低成本並
#       加速對市況變化的回應。
#     B.建置主原料丙烯?之產品商情資料庫，與優質供應商策略聯
#       盟，降低原物料進貨成本。
#     C.持續開發附加價值較高之特殊品種，並積極開發外銷市場，
#       增加產品組合。
#     D.增加合約客戶銷售比重，穩定銷量。
#  (2)財務方面
#     A.本公司銷售以外銷為主，為加強應收帳款收現週轉天數，於
#       收到客戶之遠期信用狀後，會立即出售予銀行，以提高應收
#       帳款收現率。
#     B.本公司與銀行間保持良好之融資往來，未有信用不良之紀錄
#       ，且本公司已以土地及建物作為融資額度之擔保，銀行表示
#       會持續支持本公司。
#     C.本公司擬處分部分閒置不動產，以增加營運資金藉以改善流
#       動比率。
#  　　本公司於106年5月10日董事會決議為改善公司財務結構，擬以
#  減資彌補虧損，減資比例為64.5%，減資金額為850,933仟元；另為
#  充實營運資金、健全財務體質及確保公司長遠營運發展，擬以不超
#  過30,000仟股之額度內，自股東常會決議日起一年內分五次辦理現
#  金增資私募普通股。上述議案於106年6月22日經股東常會決議通過
#  。
#  　　本公司之減少資本銷除普通股85,093仟股，每股面額10元，總
#  額850,933仟元，業於106年9月22日經金管會申報生效在案，本公
#  司經董事會決議通過訂定減資基準日為106年9月30日，並於106年
#  10月17日經台北市政府核准減資變更登記。
#
#
#  </pre></td></tr><tr class="odd"><td nowrap="" width="25%">　　 合併報表編製原則</td><td align="left"><pre style="font-family:細明體;">
#  　　子公司明細、持股比率及營業項目，請參閱附註十及附註三一
#  之附表二。
#
#  </pre></td></tr></table>,
#  <table align="center" class="main_table hasBorder" style="border-collapse:collapse;wi" width="900"><tr class="tblHead"><th align="left" colspan="35" rowspan="1">列入合併財務報表之子公司</th></tr><tr class="tblHead"><th align="center" colspan="1" rowspan="2">投資公司名稱</th><th align="center" colspan="1" rowspan="2">子公司名稱</th><th align="center" colspan="1" rowspan="2">業務性質</th><th align="center" colspan="3" rowspan="1">所持股權百分比</th><th align="center" colspan="1" rowspan="2">說明</th></tr><tr class="tblHead"><th align="center" colspan="1" rowspan="1">本期</th><th align="center" colspan="1" rowspan="1">去年年底</th><th align="center" colspan="1" rowspan="1">去年同期</th></tr><tr class="odd"><td align="left"><pre style="font-family:細明體;">東華合纖股份有限公司</pre></td><td align="left"><pre style="font-family:細明體;">東燁投資股份有限公司</pre></td><td align="left"><pre style="font-family:細明體;">一般投資業</pre></td><td align="right"><pre style="font-family:細明體;">90.00%</pre></td><td align="right"><pre style="font-family:細明體;">90.00%</pre></td><td align="right"><pre style="font-family:細明體;">90.00%</pre></td><td align="center"><pre style="font-family:細明體;"> </pre></td></tr><tr class="even"><th align="left" class="tblHead" colspan="1" nowrap="">備註</th><td align="left" colspan="6"><pre style="font-family:細明體;">　　東燁投資股份有限公司於106年5月11日經股東臨時會決議通過
#  減資退還股款6,000仟元，本公司依其減資比例於106年5月間取得
#  所退還股款5,400仟元，並調整減少非控制權益600仟元。</pre></td></tr></table>,
#  <table align="center" class="main_table hasBorder" style="border-collapse:collapse;" width="900"></table>,
#  <table align="center" class="main_table hasBorder" style="border-collapse:collapse;" width="900"><tr class="even"><td nowrap="" width="25%">　 員工福利</td><td align="left"><pre style="font-family:細明體;">
#  　　106年及105年7月1日至9月30日與106年及105年1月1日
#  至9月30日認列之確定福利計畫相關退休金費用係以105年
#  及104年12月31日精算決定之退休金成本率計算，金額分別
#  為328仟元、441仟元、985仟元及1,321仟元。
#
#  </pre></td></tr><tr class="odd"><td nowrap="" width="25%">　 所得稅</td><td align="left"><pre style="font-family:細明體;">
#  　　所得稅費用係當期所得稅及遞延所得稅之總和。期中期間
#  之所得稅係以年度為基礎進行評估，以預期年度總盈餘所適用
#  之稅率，就期中稅前損益予以計算。
#
#  </pre></td></tr><tr class="even"><td colspan="2">　 其他</td></tr><tr class="even"><td align="center" width="50%">項目</td><td align="center">說明</td></tr><tr class="odd"></tr><tr class="even"></tr><tr class="odd"></tr><tr class="even"><td colspan="2" nowrap="">重大會計判斷、假設及估計不確性之主要來源</td></tr><tr class="odd"><td nowrap="" width="25%">　 重大會計判斷、假設及估計不確性之主要來源</td><td align="left"><pre style="font-family:細明體;">
#  　　請參閱105年度合併財務報告之重大會計判斷、估計及假設不確
#  定性主要來源說明。
#
#  </pre></td></tr></table>,
#  <table align="center" class="main_table hasBorder" style="border-collapse:collapse;wi" width="900"><tr class="tblHead"><th align="left" colspan="8" rowspan="1">明細表</th></tr><tr class="tblHead"><th align="center" colspan="8" rowspan="1">項目及金額</th></tr><tr class="tblHead"><th align="center" colspan="1" rowspan="2">項目</th><th align="center" colspan="3" rowspan="1">金額</th></tr><tr class="tblHead"><th align="center" colspan="1" rowspan="1">本期</th><th align="center" colspan="1" rowspan="1">去年年底</th><th align="center" colspan="1" rowspan="1">去年同期</th></tr><tr class="odd"><td align="left"><pre style="font-family:細明體;">應收票據</pre></td><td align="right"><pre style="font-family:細明體;">30</pre></td><td align="right"><pre style="font-family:細明體;">0</pre></td><td align="right"><pre style="font-family:細明體;">28</pre></td></tr><tr class="even"><td align="left"><pre style="font-family:細明體;">應收帳款</pre></td><td align="right"><pre style="font-family:細明體;">9,642</pre></td><td align="right"><pre style="font-family:細明體;">13,894</pre></td><td align="right"><pre style="font-family:細明體;">21,643</pre></td></tr><tr class="odd"><td align="left"><pre style="font-family:細明體;">其他應收款</pre></td><td align="right"><pre style="font-family:細明體;">4,802</pre></td><td align="right"><pre style="font-family:細明體;">8,814</pre></td><td align="right"><pre style="font-family:細明體;">12,136</pre></td></tr><tr class="even"><th align="left" class="tblHead" colspan="1" nowrap="">合計</th><td align="right" colspan="1"><pre style="font-family:細明體;">14,474</pre></td><td align="right" colspan="1"><pre style="font-family:細明體;">22,708</pre></td><td align="right" colspan="1"><pre style="font-family:細明體;">33,807</pre></td></tr><tr class="odd"><th align="left" class="tblHead" colspan="1" nowrap="">說明</th><td align="left" colspan="3"><pre style="font-family:細明體;">　　合併公司對商品銷售之授信期間為30至120天。合併公司考量應
#  收款項自原始授信日至資產負債表日信用品質之任何改變。合併公
#  司評估應收款項有客觀減損證據時，個別評估其減損金額。由於歷
#  史經驗顯示逾期超過1年之應收款項無法回收，合併公司對於帳齡超
#  過1年之應收款項認列100%備抵呆帳，對於帳齡在1年內之應收款項
#  ，其備抵呆帳係參考交易對方過去拖欠記錄及分析其目前財務狀況
#  ，以估計無法回收之金額。</pre></td></tr></table>,
#  <table align="center" class="main_table hasBorder" style="border-collapse:collapse;wi" width="900"><tr class="tblHead"><th align="left" colspan="8" rowspan="1">已逾期但未減損應收款項之帳齡分析</th></tr><tr class="tblHead"><th align="center" colspan="8" rowspan="1">帳齡區間及金額</th></tr><tr class="tblHead"><th align="center" colspan="1" rowspan="2">帳齡區間</th><th align="center" colspan="3" rowspan="1">金額</th></tr><tr class="tblHead"><th align="center" colspan="1" rowspan="1">本期</th><th align="center" colspan="1" rowspan="1">去年年底</th><th align="center" colspan="1" rowspan="1">去年同期</th></tr><tr class="odd"><td align="left"><pre style="font-family:細明體;">0~60天</pre></td><td align="right"><pre style="font-family:細明體;">9,672</pre></td><td align="right"><pre style="font-family:細明體;">13,894</pre></td><td align="right"><pre style="font-family:細明體;">21,672</pre></td></tr><tr class="even"><th align="left" class="tblHead" colspan="1" nowrap="">合計</th><td align="right" colspan="1"><pre style="font-family:細明體;">9,672</pre></td><td align="right" colspan="1"><pre style="font-family:細明體;">13,894</pre></td><td align="right" colspan="1"><pre style="font-family:細明體;">21,672</pre></td></tr><tr class="odd"><th align="left" class="tblHead" colspan="1" nowrap="">說明</th><td align="left" colspan="3"><pre style="font-family:細明體;">1.以上係以立帳日為基準進行之帳齡分析。
#  2.合併公司對該等應收帳款餘額並未持有任何擔保品。
#  3.合併公司讓售應收帳款之金額與相關條款，請參閱附註二五。</pre></td></tr></table>,
#  <table align="center" class="main_table hasBorder" style="border-collapse:collapse;wi" width="900"><tr class="tblHead"><th align="left" colspan="2" rowspan="1">關係人名稱及關係</th></tr><tr class="tblHead"><th align="center" colspan="1" rowspan="1">關係人名稱</th><th align="center" colspan="1" rowspan="1">關係人關係</th></tr><tr class="odd"><td align="left"><pre style="font-family:細明體;">中菱股份有限公司（中菱公司）</pre></td><td align="left"><pre style="font-family:細明體;">實質關係人（其董事長與本公司董事長為同一人）</pre></td></tr><tr class="even"><td align="left"><pre style="font-family:細明體;">新竹投資股份有限公司（新竹投資公司）</pre></td><td align="left"><pre style="font-family:細明體;">實質關係人（其董事長與本公司董事長為二親等親屬）</pre></td></tr><tr class="odd"><td align="left"><pre style="font-family:細明體;">林河輝</pre></td><td align="left"><pre style="font-family:細明體;">管理階層（為本公司董事長）</pre></td></tr><tr class="even"><td align="left"><pre style="font-family:細明體;">林河宏</pre></td><td align="left"><pre style="font-family:細明體;">管理階層（為本公司董事）</pre></td></tr><tr class="odd"><td align="left"><pre style="font-family:細明體;">林壯儒</pre></td><td align="left"><pre style="font-family:細明體;">管理階層（為本公司董事兼總經理）</pre></td></tr><tr class="even"><td align="left"><pre style="font-family:細明體;">林壯燁</pre></td><td align="left"><pre style="font-family:細明體;">管理階層（為本公司董事）</pre></td></tr></table>,
#  <table align="center" class="main_table hasBorder" style="border-collapse: collapse;" width="900"><tr class="odd"><td nowrap="" width="25%">　 母公司及最終控制者之名稱</td><td align="left"><pre style="font-family:細明體;">
#  　　東華合纖股份有限公司
#
#  </pre></td></tr></table>,
#  <table align="center" class="main_table hasBorder" style="border-collapse:collapse;wi" width="900"><tr class="tblHead"><th align="left" colspan="15" rowspan="1">應付關係人款項</th></tr><tr class="tblHead"><th align="center" colspan="15" rowspan="1">帳列項目及關係人類別與金額</th></tr><tr class="tblHead"><th align="center" colspan="1" rowspan="2">帳列項目</th><th align="center" colspan="1" rowspan="2">關係人類別/名稱</th><th align="center" colspan="3" rowspan="1">金額</th></tr><tr class="tblHead"><th align="center" colspan="1" rowspan="1">本期</th><th align="center" colspan="1" rowspan="1">去年年底</th><th align="center" colspan="1" rowspan="1">去年同期</th></tr><tr class="odd"><td align="left"><pre style="font-family:細明體;">應付票據-關係人</pre></td><td align="left"><pre style="font-family:細明體;">實質關係人/中菱公司</pre></td><td align="right"><pre style="font-family:細明體;">17,277</pre></td><td align="right"><pre style="font-family:細明體;">23,685</pre></td><td align="right"><pre style="font-family:細明體;">23,816</pre></td></tr><tr class="even"><td align="left"><pre style="font-family:細明體;">其他應付款-關係人</pre></td><td align="left"><pre style="font-family:細明體;">實質關係人/中菱公司</pre></td><td align="right"><pre style="font-family:細明體;">32,858</pre></td><td align="right"><pre style="font-family:細明體;">5,047</pre></td><td align="right"><pre style="font-family:細明體;">5,213</pre></td></tr><tr class="odd"><th align="left" class="tblHead" colspan="2" nowrap="">合計</th><td align="right" colspan="1"><pre style="font-family:細明體;">50,135</pre></td><td align="right" colspan="1"><pre style="font-family:細明體;">28,732</pre></td><td align="right" colspan="2"><pre style="font-family:細明體;">29,029</pre></td></tr><tr class="even"><th align="left" class="tblHead" colspan="2" nowrap="">說明</th><td align="left" colspan="4"><pre style="font-family:細明體;"></pre></td></tr></table>,
#  <table align="center" class="main_table hasBorder" style="border-collapse:collapse;wi" width="900"><tr class="tblHead"><th align="left" colspan="8" rowspan="1">預付款項</th></tr><tr class="tblHead"><th align="center" colspan="8" rowspan="1">關係人類別與金額</th></tr><tr class="tblHead"><th align="center" colspan="1" rowspan="2">關係人類別/名稱</th><th align="center" colspan="3" rowspan="1">金額</th></tr><tr class="tblHead"><th align="center" colspan="1" rowspan="1">本期</th><th align="center" colspan="1" rowspan="1">去年年底</th><th align="center" colspan="1" rowspan="1">去年同期</th></tr><tr class="odd"><td align="left"><pre style="font-family:細明體;">實質關係人/中菱公司</pre></td><td align="right"><pre style="font-family:細明體;">800</pre></td><td align="right"><pre style="font-family:細明體;">1,123</pre></td><td align="right"><pre style="font-family:細明體;">728</pre></td></tr><tr class="even"><th align="left" class="tblHead" colspan="1" nowrap="">合計</th><td align="right" colspan="1"><pre style="font-family:細明體;">800</pre></td><td align="right" colspan="1"><pre style="font-family:細明體;">1,123</pre></td><td align="right" colspan="1"><pre style="font-family:細明體;">728</pre></td></tr><tr class="odd"><th align="left" class="tblHead" colspan="1" nowrap="">說明</th><td align="left" colspan="3"><pre style="font-family:細明體;">　　預付設備款係合併公司委託中菱公司組裝機器設備等工程產
#  生。</pre></td></tr></table>,
#  <table align="center" class="main_table hasBorder" style="border-collapse:collapse;wi" width="900"><tr class="tblHead"><th align="left" colspan="8" rowspan="1">向關係人借款</th></tr><tr class="tblHead"><th align="center" colspan="8" rowspan="1">關係人類別與金額</th></tr><tr class="tblHead"><th align="center" colspan="1" rowspan="2">關係人類別/名稱</th><th align="center" colspan="3" rowspan="1">金額</th></tr><tr class="tblHead"><th align="center" colspan="1" rowspan="1">本期</th><th align="center" colspan="1" rowspan="1">去年年底</th><th align="center" colspan="1" rowspan="1">去年同期</th></tr><tr class="odd"><td align="left"><pre style="font-family:細明體;">實質關係人-新竹投資公司</pre></td><td align="right"><pre style="font-family:細明體;">25,000</pre></td><td align="right"><pre style="font-family:細明體;">0</pre></td><td align="right"><pre style="font-family:細明體;">0</pre></td></tr><tr class="even"><th align="left" class="tblHead" colspan="1" nowrap="">合計</th><td align="right" colspan="1"><pre style="font-family:細明體;">25,000</pre></td><td align="right" colspan="1"><pre style="font-family:細明體;">0</pre></td><td align="right" colspan="1"><pre style="font-family:細明體;">0</pre></td></tr><tr class="odd"><th align="left" class="tblHead" colspan="1" nowrap="">說明</th><td align="left" colspan="3"><pre style="font-family:細明體;">帳列項目     關係人類別／名稱         106年7月1日    105年7月1日    106年1月1日    105年1月1日
#                                          至9月30日      至9月30日      至9月30日      至9月30日
#  利息費用     實質關係人/新竹投資公司   $      39      $	      -	     $	    39      $	    -
#
#  　　合併公司向關係人借款之借款利率為2.36%，與市場利率相當。
#  </pre></td></tr></table>,
#  <table align="center" class="main_table hasBorder" style="border-collapse: collapse;" width="900"><tr class="odd"><td nowrap="" width="25%">　　 其它</td><td align="left"><pre style="font-family:細明體;">
#  帳列項目       關係人類別／名稱	     106年9月30日     105年12月31日    105年9月30日
#  存出保證金     實質關係人/中菱公司   $    10,000      $	    10,000     $    10,000
#
#  　　存出保證金係合併公司向中菱公司承租湖口鄉倉庫之押金及委託該公司負責亞克力棉條成品之打包及原料、
#  成品運送之履約保證金。
#
#  帳列項目             關係人類別/名稱	 106年7月1日    105年7月1日    106年1月1日    105年1月1日
#                                             至9月30日      至9月30日      至9月30日      至9月30日
#  營業成本－原物料運費 實質關係人		 $    8,221     $   10,468     $   32,773     $   37,413
#  營業成本－修繕費     實質關係人               2,221          1,995          5,813          5,400
#  營業成本－雜費	     實質關係人               1,361          1,330          4,037          4,049
#  營業成本－租金費用   實質關係人                 840            840          2,520          2,520
#  營業費用－運費	     實質關係人/中菱公司      3,124          4,270         11,802         13,960
#  營業費用－出口費用   實質關係人               1,107          1,769          4,147          5,186
#
#  　　營業成本－原物料運費、營業費用－運費及營業費用－出口費用係合併公司委託中菱公司負責原料及成品
#  之運送。
#  　　營業成本－修繕費係合併公司委託中菱公司進行廠房及設備修繕之支出。
#  　　營業成本－雜費係合併公司委託中菱公司進行煤場清潔及管理之支出。
#  　　營業成本－租金費用係合併公司向中菱公司承租湖口鄉倉庫之支出，每月租金為280仟元，每月支付。
#
#
#
#  </pre></td></tr></table>,
#  <table align="center" class="main_table hasBorder" style="border-collapse:collapse;wi" width="900"><tr class="tblHead"><th align="left" colspan="13" rowspan="1">被投資公司名稱、所在地區…等相關資訊</th></tr><tr class="tblHead"><th align="center" colspan="1" rowspan="2">投資公司名稱</th><th align="center" colspan="1" rowspan="2">被投資公司名稱</th><th align="center" colspan="1" rowspan="2">地區別代號</th><th align="center" colspan="1" rowspan="2">所在地區</th><th align="center" colspan="1" rowspan="2">主要營業項目</th><th align="center" colspan="2" rowspan="1">原始投資金額</th><th align="center" colspan="3" rowspan="1">期末持股情形</th><th align="center" colspan="1" rowspan="2">被投資公司本期損益</th><th align="center" colspan="1" rowspan="2">本期認列之投資損益</th><th align="center" colspan="1" rowspan="2">備註</th></tr><tr class="tblHead"><th align="center" colspan="1" rowspan="1">本期期末</th><th align="center" colspan="1" rowspan="1">去年年底</th><th align="center" colspan="1" rowspan="1">股數</th><th align="center" colspan="1" rowspan="1">比率</th><th align="center" colspan="1" rowspan="1">帳面金額</th></tr><tr class="odd"><td align="left"><pre style="font-family:細明體;">東華合纖股份有限公司</pre></td><td align="left"><pre style="font-family:細明體;">東燁投資股份有限公司</pre></td><td align="left"><pre style="font-family:細明體;">0</pre></td><td align="left"><pre style="font-family:細明體;">台灣</pre></td><td align="left"><pre style="font-family:細明體;">一般投資業</pre></td><td align="right"><pre style="font-family:細明體;">99,000</pre></td><td align="right"><pre style="font-family:細明體;">104,400</pre></td><td align="right"><pre style="font-family:細明體;">5,850,000</pre></td><td align="right"><pre style="font-family:細明體;">90.00%</pre></td><td align="right"><pre style="font-family:細明體;">4,236</pre></td><td align="right"><pre style="font-family:細明體;">1,322</pre></td><td align="right"><pre style="font-family:細明體;">-165</pre></td><td align="left"><pre style="font-family:細明體;">子公司(註)</pre></td></tr><tr class="even"><td align="left"><pre style="font-family:細明體;">東華合纖股份有限公司</pre></td><td align="left"><pre style="font-family:細明體;">碳能科技股份有限公司</pre></td><td align="left"><pre style="font-family:細明體;">0</pre></td><td align="left"><pre style="font-family:細明體;">台灣</pre></td><td align="left"><pre style="font-family:細明體;">碳紙、碳布及碳纖維布之加工、製造及零售</pre></td><td align="right"><pre style="font-family:細明體;">30,000</pre></td><td align="right"><pre style="font-family:細明體;">30,000</pre></td><td align="right"><pre style="font-family:細明體;">3,000,000</pre></td><td align="right"><pre style="font-family:細明體;">12.44%</pre></td><td align="right"><pre style="font-family:細明體;">6,238</pre></td><td align="right"><pre style="font-family:細明體;">-7,746</pre></td><td align="right"><pre style="font-family:細明體;">-964</pre></td><td align="left"><pre style="font-family:細明體;">關聯企業</pre></td></tr><tr class="odd"><th align="left" class="tblHead" colspan="1" nowrap="">備註</th><td align="left" colspan="12"><pre style="font-family:細明體;">註：於編製本合併財務報表時，業已合併沖銷。</pre></td></tr></table>]
